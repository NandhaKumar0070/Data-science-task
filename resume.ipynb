# %% [markdown]
# <b><center><font size="10">Nandha Kumar P</font></center>

# %% [markdown]
# ![20220126_141157%20%284%29.jpg](attachment:20220126_141157%20%284%29.jpg)

# %% [markdown]
# <u><font size="5">Personal Data:</font></u>
# ***
# > Gender   : Male
#
# > D.O.B    : 16 November 2001
#
# > Ph.no    : +91 9952395339
#
# > Email    : [nandharavichandran2001@gmail.com](https://mail.google.com/mail/u/0/#inbox?compose=GTvVlcSPFqzlSctRPGlbvHhLNsSlTkqvzHVxwqLjrzMmRGnrcThjTHVlMkzJCxWVZvsFFfKdnDTDq)
#
# > LinkedIn : [Nandha Kumar](https://www.linkedin.com/in/nandha-kumar-23a05b235/)

# %% [markdown]
# <u><font size="5">Education</font></u>
# ***
# > 2019-2023 |   Under Graduation
#
# >Rajalakshmi Engineering College,Chennai
#
# >2018-2019   | Higher Secoundary
#
# >Shree Nikathen Matriculation Hr Sec School,Thiruvallur

# %% [markdown]
# <u><font size="5">Project</font></u>
# ***
# <font size="3">CARTOONISED IMAGE FILTER</font>
# * Used KMEANS Algorithm and Gausian Blur to cartoonise an image.
#
# * Worked on report generation and presented the report, acted as Technical member of the team.
#
# <font size="3">FACE MASK DETECTION</font>
# * Used Keras library and SKlearn to Identify the presence of mask.
#
# * Worked on report and presented the project to the Mentor for evaluation of mini project.

# %% [markdown]
# <u><font size="10">Acheivements</font></u>
# ***
# * Won Special Prize for Cartoonised Image Filter project on Project Expo held on university during National Technology Day -22.
#
# * Worked on Report building and Project Presentation to the audience.

# %% [markdown]
# <u><font size="10">Certifications</font></u>
# ***
# * Project Management Fundamental
# * Fullstack Development
# * Design & Implementation of Human-Computer Interfaces

# %% [markdown]
# <u><font size="10">Hobbies</font></u>
# ***
# * Cooking
# * Gaming
# * lisenting to music
# * Watching anime
# * reading manga
